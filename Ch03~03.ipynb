# %% [markdown]
# <a href="https://colab.research.google.com/github/rickiepark/the-ml-book/blob/main/Ch03~03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 결정 트리

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True, as_frame=True)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X, y)
# Out:
# 1.0

# %%
model = DecisionTreeClassifier(max_depth=2)
model.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
model.score(X, y)
# Out:
# 0.96

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plot_tree(model, filled=True)
plt.show()

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=2)
model.fit(X, y).score(X, y)
# Out:
# 0.96

# %%
from sklearn.datasets import fetch_california_housing

X, y = fetch_california_housing(return_X_y=True, as_frame=True)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth=10)
model.fit(X, y)
model.score(X, y)
# Out:
# 0.8206970165223322

# %%
from sklearn.metrics import mean_absolute_error

y_hat = model.predict(X)
mean_absolute_error(y, y_hat)
# Out:
# 0.3342488490418862
