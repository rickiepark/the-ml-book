# %% [markdown]
# <a href="https://colab.research.google.com/github/rickiepark/the-ml-book/blob/main/Ch03~05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # k-최근접 이웃

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True, as_frame=True)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=5) # n_neighbors=5 기본값
model.fit(X, y)
model.score(X, y)
# Out:
# 0.9666666666666667

# %%
model.kneighbors(X[0:1])
# Out:
# (array([[0.        , 0.1       , 0.14142136, 0.14142136, 0.14142136]]),
#  array([[ 0, 17,  4, 39, 28]]))

# %%
from sklearn.datasets import fetch_california_housing

X, y = fetch_california_housing(return_X_y=True, as_frame=True)

# %%
from sklearn.preprocessing import StandardScaler

X_trans = StandardScaler().fit_transform(X)

# %%
from sklearn.neighbors import KNeighborsRegressor

model = KNeighborsRegressor().fit(X_trans, y)
model.score(X_trans, y)
# Out:
# 0.7985691404441083

# %%
from sklearn.metrics import mean_absolute_error

y_hat = model.predict(X_trans)
mean_absolute_error(y, y_hat)
# Out:
# 0.3503088939922481
